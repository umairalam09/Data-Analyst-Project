# %% [markdown]
# <a href="https://colab.research.google.com/github/umairalam09/Data-Analyst-Project/blob/main/Loan_Analysis_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import math

import numpy as np
# Out:
# <ipython-input-3-6372bf86d92a>:4: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math

# %%
 df = pd.read_csv('/content/loan_sanction_test.csv')
 df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop(['Credit_History'], axis = 1, inplace = True)

# %%
df_2 = df.dropna(axis =0)
sns.heatmap(df_2.isnull())
# Out:
# <Axes: >

# %%
df_2.describe( include='object')
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 314 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            314 non-null    object
#  1   Gender             314 non-null    object
#  2   Married            314 non-null    object
#  3   Dependents         314 non-null    object
#  4   Education          314 non-null    object
#  5   Self_Employed      314 non-null    object
#  6   ApplicantIncome    314 non-null    int64
#  7   CoapplicantIncome  314 non-null    int64
#  8   LoanAmount         314 non-null    float64
#  9   Loan_Amount_Term   314 non-null    float64
#  10  Property_Area      314 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 29.4+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Property_Area         0
# dtype: int64

# %%
df_2.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# dtype: int64

# %%
sns.set_style('dark')

# %%
df_2['LoanAmount'].mean()
# Out:
# 136.5859872611465

# %%
df_2['LoanAmount'].median()
# Out:
# 125.5

# %%
df_2['LoanAmount'].mode()
# Out:
# 0    150.0
# Name: LoanAmount, dtype: float64

# %%
df_2['Loan_Amount_term'] =

# %%
enocder = {'Self_Employment': {'Yes': 1, 'No': 0},
           'Married': {'Yes': 1, 'No': 0},
           'Education': {'Graduate': 1, 'Not Graduate': 0},
           'Property_Area': {'Urban': 2, 'Semiurban': 1, 'Rural': 0},
           'Gender': {'Male': 1, 'Female': 0}}
df_2.replace(enocder, inplace=True)
# Out:
# <ipython-input-9-f283396e0105>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.replace(enocder, inplace=True)

# %%
df_2.to_csv('loan_sanction_test.csv')

# %%
pd.set_option('display.max_rows', None)
df_2
# Out:
#       Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0    LP001015       1        1          0          1            No
# 1    LP001022       1        1          1          1            No
# 2    LP001031       1        1          2          1            No
# 3    LP001035       1        1          2          1            No
# 4    LP001051       1        0          0          0            No
# 5    LP001054       1        1          0          0           Yes
# 6    LP001055       0        0          1          0            No
# 7    LP001056       1        1          2          0            No
# 9    LP001067       1        0          0          0            No
# 10   LP001078       1        0          0          0            No
# 12   LP001083       1        0         3+          1            No
# 14   LP001096       0        0          0          1            No
# 15   LP001099       1        0          1          1            No
# ...

# %%
len(df_2('LoanAMo'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7e1af04585ad> in <cell line: 1>()
# ----> 1 len(df_2('LoanAMo'))
#
# TypeError: 'DataFrame' object is not callable

# %%
perc = df_2['Property_Area'].value_counts(normalize=True)*100
perc
# Out:
# Property_Area
# 2    38.535032
# 1    30.891720
# 0    30.573248
# Name: proportion, dtype: float64

# %%
df_2[['ApplicantIncome', 'LoanAmount']].corr()
# Out:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome         1.000000    0.508676
# LoanAmount              0.508676    1.000000

# %%
sns.scatterplot(x = 'ApplicantIncome', y = 'LoanAmount', data = df_2,color = 'g')
plt.title('Loan Amoun taken According to Applicant Income')
plt.show()

# %%
perc2 = df_2['Property_Area'].value_counts(normalize=True)*100
perc2
# Out:
# Property_Area
# Urban        39.100346
# Rural        30.795848
# Semiurban    30.103806
# Name: proportion, dtype: float64

# %%
sns.barplot(x = 'Property_Area' , y ='LoanAmount', data = df_2, color = 'b')
plt.title('Applicant Money in Accordance to Property Area')
plt.show()

# %%
sns.boxplot(x ='Education', y = 'LoanAmount', hue = 'Gender', data = df_2, color = 'b', linewidth = 1 , showmeans = True)
plt.title('Loan Amount Taken as per Graduation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2fe19678102a> in <cell line: 1>()
# ----> 1 sns.boxplot(x ='Education', y = 'LoanAmount', hue = 'Gender', data = df_2, color = 'b', linewidth = 1 , showmeans = True)
#       2 plt.title('Loan Amount Taken as per Graduation')
#       3 plt.show()
#
# NameError: name 'df_2' is not defined

# %%
sns.barplot( x = 'Self_Employed', y = 'LoanAmount', hue = 'Dependents', color = 'y', width = 0.8 , data = df_2,)
plt.title('Loan AMount According to Self Employment')
plt.show()
# Out:
# <ipython-input-76-7ba726a85351>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:y'` for the same effect.
#
#   sns.barplot( x = 'Self_Employed', y = 'LoanAmount', hue = 'Dependents', color = 'y', width = 0.8 , data = df_2,)

# %%
df_2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#   Property_Area
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban

# %%
df_2.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# dtype: int64

# %%
import plotly.express as px

# %%
px.( df_2, x = 'ApplicantIncome', y = 'LoanAmount', color = 'Gender',)
# Out:
#   File "<ipython-input-19-e7783544933c>", line 1
#     px.( df_2, x = 'ApplicantIncome', y = 'LoanAmount', color = 'Gender',)
#        ^
# SyntaxError: invalid syntax

# %%
dpx.bar(df_2,x ='Gender', y = 'LoanAmount', color = 'Self_Employed', )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df_2, x = 'ApplicantIncome', y = 'LoanAmount', color = 'Gender', hover_name = 'Self_Employed')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.pairplot(df_2)

# %%
px.box(df_2,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-477bb9071897> in <cell line: 1>()
# ----> 1 px.box(df_2,)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, template, width, height)
#     664     range (IQR: Q3-Q1), see "points" for other options.
#     665     """
# --> 666     return make_figure(
#     667         args=locals(),
#     668         constructor=go.Box,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
# ...

# %%
numeric_features = df_2.select_dtypes(include = ['int64',])
numeric_features.corr()
# Out:
#                      Gender   Married  Education  ApplicantIncome  \
# Gender             1.000000  0.275606  -0.005081         0.061205
# Married            0.275606  1.000000  -0.022499         0.073786
# Education         -0.005081 -0.022499   1.000000         0.133379
# ApplicantIncome    0.061205  0.073786   0.133379         1.000000
# CoapplicantIncome  0.081846  0.036285   0.061624        -0.097781
# Property_Area     -0.046856 -0.023398  -0.013193         0.027950
#
#                    CoapplicantIncome  Property_Area
# Gender                      0.081846      -0.046856
# Married                     0.036285      -0.023398
# Education                   0.061624      -0.013193
# ApplicantIncome            -0.097781       0.027950
# CoapplicantIncome           1.000000      -0.096015
# Property_Area              -0.096015       1.000000

# %%
plt.figure(figsize=(15,8))
correlation = numeric_features.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
for col in numeric_features[1:]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df_2[col]
    feature.hist(bins=50, ax = ax)
    ax.axvline(feature.mean(), color='magenta', linestyle='dashed', linewidth=2)
    ax.axvline(feature.median(), color='cyan', linestyle='dashed', linewidth=2)
    ax.set_title(col)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.distplot(np.log10(df_2['LoanAmount']),color="y"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72861d4c1bb3> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(8,7))
#       2 sns.distplot(np.log10(df_2['LoanAmount']),color="y"
#       3 )
#
# NameError: name 'plt' is not defined

# %%
sns.kdeplot(df_2['LoanAmount'],color="y")
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
df_2.LoanAmount.skew()
# Out:
# 1.780616236319326

# %%
df_2['LoanAmount_transformed'] = np.log10(df_2['LoanAmount'])
# Out:
# <ipython-input-27-6c9ce73a3bad>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_2.LoanAmount_transformed.skew()
# Out:
# -0.8594664783324462

# %%
sns.kdeplot(df_2['LoanAmount_transformed'],color="y")
# Out:
# <Axes: xlabel='LoanAmount_transformed', ylabel='Density'>

# %%
sns.boxplot(data = df_2, width = 0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b9de88c7032a> in <cell line: 1>()
# ----> 1 sns.boxplot(data = df_2, width = 0.5, length = 10)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1631     linecolor = p._complement_color(linecolor, color, p._hue_map)
#    1632
# -> 1633     p.plot_boxes(
#    1634         width=width,
#    1635         dodge=dodge,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     697             )
#     698             boxplot_kws = {**default_kws, **plot_kws}
# ...
